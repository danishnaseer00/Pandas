# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/matches.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.tail()
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
df.shape
# Out:
# (636, 18)

# %%
df.shape[-1]
# Out:
# 18

# %%
df.shape[1]
# Out:
# 18

# %%
df.shape[0]
# Out:
# 636

# %%
df.shape[-5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-91-447892686> in <cell line: 0>()
# ----> 1 df.shape[-5]
#
# IndexError: tuple index out of range

# %%
df.info()  # In formation about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
df.describe()  # gives you numeric data and apply some mathematical functions over the data
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df['id']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 631    632
# 632    633
# 633    634
# 634    635
# 635    636
# Name: id, Length: 636, dtype: int64

# %%
df['id'][1]
# Out:
# np.int64(2)

# %%
df[['team1' , 'team2' , 'winner']]  # without iloc,, fetching the rows from the data
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
df[['team1' , 'team2' , 'winner']].shape
# Out:
# (636, 3)

# %%
df.iloc[1]
# Out:
# id                                                       2
# season                                                2017
# city                                                  Pune
# date                                            2017-04-06
# team1                                       Mumbai Indians
# team2                               Rising Pune Supergiant
# toss_winner                         Rising Pune Supergiant
# toss_decision                                        field
# result                                              normal
# dl_applied                                               0
# winner                              Rising Pune Supergiant
# win_by_runs                                              0
# win_by_wickets                                           7
# player_of_match                                  SPD Smith
# venue              Maharashtra Cricket Association Stadium
# umpire1                                     A Nand Kishore
# ...

# %%
df.iloc[-1]   # Gives you last row
# Out:
# id                                         636
# season                                    2016
# city                                 Bangalore
# date                                2016-05-29
# team1                      Sunrisers Hyderabad
# team2              Royal Challengers Bangalore
# toss_winner                Sunrisers Hyderabad
# toss_decision                              bat
# result                                  normal
# dl_applied                                   0
# winner                     Sunrisers Hyderabad
# win_by_runs                                  8
# win_by_wickets                               0
# player_of_match                    BCJ Cutting
# venue                    M Chinnaswamy Stadium
# umpire1                        HDPK Dharmasena
# umpire2                           BNJ Oxenford
# umpire3                                    NaN
# Name: 635, dtype: object

# %%
df.iloc[1:4]  # slicing is same as used in python.. default use for rows fetching
# Out:
#    id  season    city        date                   team1  \
# 1   2    2017    Pune  2017-04-06          Mumbai Indians
# 2   3    2017  Rajkot  2017-04-07           Gujarat Lions
# 3   4    2017  Indore  2017-04-08  Rising Pune Supergiant
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders   Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab         Kings XI Punjab         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 2           0   Kolkata Knight Riders            0              10
# 3           0         Kings XI Punjab            0               6
#
#   player_of_match                                    venue         umpire1  \
# 1       SPD Smith  Maharashtra Cricket Association Stadium  A Nand Kishore
# ...

# %%
df.head()   # Gives you top 5 rows of data
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.iloc[[1,3,5]]   # Fancy indexing.. will give you 1 ,3 and 5 column
# Out:
#    id  season       city        date                   team1  \
# 1   2    2017       Pune  2017-04-06          Mumbai Indians
# 3   4    2017     Indore  2017-04-08  Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09           Gujarat Lions
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 3         Kings XI Punjab         Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 3           0         Kings XI Punjab            0               6
# 5           0     Sunrisers Hyderabad            0               9
#
#   player_of_match                                      venue         umpire1  \
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
# ...

# %%
df.iloc[:,[4,5,9]]
# Out:
#                            team1                        team2  dl_applied
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore           0
# 1                 Mumbai Indians       Rising Pune Supergiant           0
# 2                  Gujarat Lions        Kolkata Knight Riders           0
# 3         Rising Pune Supergiant              Kings XI Punjab           0
# 4    Royal Challengers Bangalore             Delhi Daredevils           0
# ..                           ...                          ...         ...
# 631             Delhi Daredevils  Royal Challengers Bangalore           0
# 632                Gujarat Lions  Royal Challengers Bangalore           0
# 633          Sunrisers Hyderabad        Kolkata Knight Riders           0
# 634                Gujarat Lions          Sunrisers Hyderabad           0
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore           0
#
# [636 rows x 3 columns]

# %%
df.iloc[1:4, [4,5,10]]
# iloc also used for frtching columns. Like Numpy, You can also use fancing indexing or slicing for fetching the rows and columns
# Out:
#                     team1                   team2                  winner
# 1          Mumbai Indians  Rising Pune Supergiant  Rising Pune Supergiant
# 2           Gujarat Lions   Kolkata Knight Riders   Kolkata Knight Riders
# 3  Rising Pune Supergiant         Kings XI Punjab         Kings XI Punjab

# %% [markdown]
# **Masking using Booleans-- Fitering using conditions**

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
type(df['city'] == 'Pune')
# Out:
# pandas.core.series.Series

# %%
mask = df['city'] == 'Hyderabad'

# %%
mask
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: city, Length: 636, dtype: bool

# %%
df[mask]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 65    66    2008  Hyderabad  2008-04-22              Deccan Chargers
# 67    68    2008  Hyderabad  2008-04-24              Deccan Chargers
# 76    77    2008  Hyderabad  2008-05-01              Deccan Chargers
# 79    80    2008  Hyderabad  2008-05-25              Deccan Chargers
# 91    92    2008  Hyderabad  2008-05-11        Kolkata Knight Riders
# ...

# %%
df[mask].shape
# Out:
# (49, 18)

# %%
# Function for Finding number of matches in a city...  We can make similar functions..
def match_in_city(city):
  mask = df['city'] == city
  return df[mask].shape[0]

# %%
match_in_city('Pune')
# Out:
# 32

# %%
match_in_city('Mumbai')
# Out:
# 85

# %%
mask1 = df['team1'] == 'Mumbai Indians'
mask2 = df['win_by_wickets'] == 7

df[mask1 & mask2].shape
# Out:
# (15, 18)

# %% [markdown]
# ***Value-Counts() --- Tells frequency in categorical data***

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df['city'].value_counts()
# Out:
# city
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Port Elizabeth     7
# Ranchi             7
# Abu Dhabi          7
# Cuttack            7
# Raipur             6
# Sharjah            6
# Indore             5
# Kochi              5
# Kanpur             4
# East London        3
# Kimberley          3
# Nagpur             3
# Bloemfontein       2
# Name: count, dtype: int64

# %% [markdown]
# # **Pandas Plot-functions**

# %%
import matplotlib.pyplot as plt

# %%
df['winner'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %%
df['winner'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
series = df['city'].value_counts()

# %%
series
# Out:
# city
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Port Elizabeth     7
# Ranchi             7
# Abu Dhabi          7
# Cuttack            7
# Raipur             6
# Sharjah            6
# Indore             5
# Kochi              5
# Kanpur             4
# East London        3
# Kimberley          3
# Nagpur             3
# Bloemfontein       2
# Name: count, dtype: int64

# %%
series.index  # .index will give the indexes in array format
# Out:
# Index(['Mumbai', 'Bangalore', 'Kolkata', 'Delhi', 'Hyderabad', 'Chennai',
#        'Chandigarh', 'Jaipur', 'Pune', 'Durban', 'Centurion', 'Ahmedabad',
#        'Visakhapatnam', 'Rajkot', 'Dharamsala', 'Johannesburg', 'Cape Town',
#        'Port Elizabeth', 'Ranchi', 'Abu Dhabi', 'Cuttack', 'Raipur', 'Sharjah',
#        'Indore', 'Kochi', 'Kanpur', 'East London', 'Kimberley', 'Nagpur',
#        'Bloemfontein'],
#       dtype='object', name='city')

# %%
series.values  # give values of the indexes
# Out:
# array([85, 66, 61, 60, 49, 48, 46, 33, 32, 15, 12, 12, 11, 10,  9,  8,  7,
#         7,  7,  7,  7,  6,  6,  5,  5,  4,  3,  3,  3,  2])

# %%
df['team1'].value_counts() + df['winner'].value_counts()
# Out:
# Chennai Super Kings            156
# Deccan Chargers                 72
# Delhi Daredevils               125
# Gujarat Lions                   27
# Kings XI Punjab                147
# Kochi Tuskers Kerala            13
# Kolkata Knight Riders          145
# Mumbai Indians                 174
# Pune Warriors                   32
# Rajasthan Royals               117
# Rising Pune Supergiant          18
# Rising Pune Supergiants         12
# Royal Challengers Bangalore    143
# Sunrisers Hyderabad             88
# Name: count, dtype: int64

# %% [markdown]
# ***sort-function on Series and dataframes***

# %%
(df['team1'].value_counts() + df['winner'].value_counts()).sort_values()
# Out:
# Rising Pune Supergiants         12
# Kochi Tuskers Kerala            13
# Rising Pune Supergiant          18
# Gujarat Lions                   27
# Pune Warriors                   32
# Deccan Chargers                 72
# Sunrisers Hyderabad             88
# Rajasthan Royals               117
# Delhi Daredevils               125
# Royal Challengers Bangalore    143
# Kolkata Knight Riders          145
# Kings XI Punjab                147
# Chennai Super Kings            156
# Mumbai Indians                 174
# Name: count, dtype: int64

# %%
(df['team1'].value_counts() + df['winner'].value_counts()).sort_values(ascending=False)
# For Series
# Out:
# Mumbai Indians                 174
# Chennai Super Kings            156
# Kings XI Punjab                147
# Kolkata Knight Riders          145
# Royal Challengers Bangalore    143
# Delhi Daredevils               125
# Rajasthan Royals               117
# Sunrisers Hyderabad             88
# Deccan Chargers                 72
# Pune Warriors                   32
# Gujarat Lions                   27
# Rising Pune Supergiant          18
# Kochi Tuskers Kerala            13
# Rising Pune Supergiants         12
# Name: count, dtype: int64

# %%
df['winner'].sort_values()
# Out:
# 70     Chennai Super Kings
# 473    Chennai Super Kings
# 210    Chennai Super Kings
# 86     Chennai Super Kings
# 546    Chennai Super Kings
#               ...
# 524    Sunrisers Hyderabad
# 635    Sunrisers Hyderabad
# 300                    NaN
# 545                    NaN
# 570                    NaN
# Name: winner, Length: 636, dtype: object

# %%
# for Dataframes
df.sort_values('winner' , ascending=False)
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 502  503    2014  Hyderabad  2014-05-20  Royal Challengers Bangalore
# 488  489    2014      Delhi  2014-05-10             Delhi Daredevils
# 486  487    2014  Ahmedabad  2014-05-08          Sunrisers Hyderabad
# ..   ...     ...        ...         ...                          ...
# 546  547    2015    Chennai  2015-04-28          Chennai Super Kings
# 489  490    2014     Mumbai  2014-05-10               Mumbai Indians
# 300  301    2011      Delhi  2011-05-21             Delhi Daredevils
# 545  546    2015  Bangalore  2015-04-29  Royal Challengers Bangalore
# 570  571    2015  Bangalore  2015-05-17             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
# For multiple series
df.sort_values(['winner' , 'city'] , ascending=[True , False])
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 473  474    2014        Sharjah  2014-04-27          Sunrisers Hyderabad
# 477  478    2014         Ranchi  2014-05-02          Chennai Super Kings
# 493  494    2014         Ranchi  2014-05-13             Rajasthan Royals
# 574  575    2015         Ranchi  2015-05-22  Royal Challengers Bangalore
# ..   ...     ...            ...         ...                          ...
# 468  469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 476  477    2014            NaN  2014-04-30          Sunrisers Hyderabad
# 300  301    2011          Delhi  2011-05-21             Delhi Daredevils
# 545  546    2015      Bangalore  2015-04-29  Royal Challengers Bangalore
# 570  571    2015      Bangalore  2015-05-17             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
# If we write (implace = True), it will change the data in actually file(e.g csv.)
# So use it carefully

# %%
# Drop_duplicates.. For removing the duplicate values
# and use (subset) keyword for multiple cols duplicate removal

# %%
df.drop_duplicates('city')
# Out:
#       id  season            city        date                        team1  \
# 0      1    2017       Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017            Pune  2017-04-06               Mumbai Indians
# 2      3    2017          Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017          Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017       Bangalore  2017-04-08  Royal Challengers Bangalore
# 6      7    2017          Mumbai  2017-04-09        Kolkata Knight Riders
# 10    11    2017         Kolkata  2017-04-13              Kings XI Punjab
# 14    15    2017           Delhi  2017-04-15             Delhi Daredevils
# 31    32    2017      Chandigarh  2017-04-28          Sunrisers Hyderabad
# 48    49    2017          Kanpur  2017-05-10                Gujarat Lions
# 64    65    2008          Jaipur  2008-04-21              Kings XI Punjab
# 66    67    2008         Chennai  2008-04-23          Chennai Super Kings
# ...

# %%
df.drop_duplicates('winner').head()['winner'].sort_values()
# Out:
# 3                Kings XI Punjab
# 2          Kolkata Knight Riders
# 1         Rising Pune Supergiant
# 4    Royal Challengers Bangalore
# 0            Sunrisers Hyderabad
# Name: winner, dtype: object

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.drop_duplicates(subset=['team1' , 'team2', 'winner'] , keep='last')[['team1' ,'team2' ,'winner']].sort_values('winner').head(10)
# Out:
#                            team1                 team2               winner
# 473          Sunrisers Hyderabad   Chennai Super Kings  Chennai Super Kings
# 263                Pune Warriors   Chennai Super Kings  Chennai Super Kings
# 453          Chennai Super Kings        Mumbai Indians  Chennai Super Kings
# 518          Chennai Super Kings      Delhi Daredevils  Chennai Super Kings
# 520          Chennai Super Kings   Sunrisers Hyderabad  Chennai Super Kings
# 113              Deccan Chargers   Chennai Super Kings  Chennai Super Kings
# 296          Chennai Super Kings  Kochi Tuskers Kerala  Chennai Super Kings
# 493             Rajasthan Royals   Chennai Super Kings  Chennai Super Kings
# 574  Royal Challengers Bangalore   Chennai Super Kings  Chennai Super Kings
# 482             Delhi Daredevils   Chennai Super Kings  Chennai Super Kings

# %%
mask0 = df.drop_duplicates(subset=['team1' , 'team2', 'winner'] , keep='last')[['team1' ,'team2' ,'winner']].sort_values('winner').head(10)
new_mask = mask0['winner'] != 'Chennai Super Kings'

# %%
df[new_mask]
# Out:
# <ipython-input-137-3782980890>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[new_mask]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-137-3782980890> in <cell line: 0>()
# ----> 1 df[new_mask]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4091         # Do we have a (boolean) 1d indexer?
#    4092         if com.is_bool_indexer(key):
# -> 4093             return self._getitem_bool_array(key)
#    4094
#    4095         # We are left with two options: a single key, and a collection of keys,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    4147         # check_bool_indexer will throw exception if Series key cannot
#    4148         # be reindexed to match DataFrame rows
# ...

# %% [markdown]
# ***GroupBY()***

# %%
df.head(2)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2  umpire3
# 0  NJ Llong      NaN
# 1    S Ravi      NaN

# %%
city = df.groupby('city')

# %%
 df.groupby('city').size().sort_values(ascending=False)
# Out:
# city
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Ahmedabad         12
# Centurion         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Ranchi             7
# Cuttack            7
# Abu Dhabi          7
# Port Elizabeth     7
# Cape Town          7
# Raipur             6
# Sharjah            6
# Kochi              5
# Indore             5
# Kanpur             4
# Kimberley          3
# East London        3
# Nagpur             3
# Bloemfontein       2
# dtype: int64

# %%
city.size()
# Out:
# city
# Abu Dhabi          7
# Ahmedabad         12
# Bangalore         66
# Bloemfontein       2
# Cape Town          7
# Centurion         12
# Chandigarh        46
# Chennai           48
# Cuttack            7
# Delhi             60
# Dharamsala         9
# Durban            15
# East London        3
# Hyderabad         49
# Indore             5
# Jaipur            33
# Johannesburg       8
# Kanpur             4
# Kimberley          3
# Kochi              5
# Kolkata           61
# Mumbai            85
# Nagpur             3
# Port Elizabeth     7
# Pune              32
# Raipur             6
# Rajkot            10
# Ranchi             7
# Sharjah            6
# Visakhapatnam     11
# dtype: int64

# %%
df['city'].value_counts()['Mumbai']
# Out:
# np.int64(85)

# %%
city.first() # will take first row of the multiple rows in a group.. e.g mumbai has 85 number so it will pick up first row..
# Out:
#                  id  season        date                        team1  \
# city
# Abu Dhabi       458    2014  2014-04-16        Kolkata Knight Riders
# Ahmedabad       180    2010  2010-03-15             Rajasthan Royals
# Bangalore         5    2017  2017-04-08  Royal Challengers Bangalore
# Bloemfontein    161    2009  2009-05-15             Delhi Daredevils
# Cape Town       118    2009  2009-04-18               Mumbai Indians
# Centurion       133    2009  2009-04-28             Delhi Daredevils
# Chandigarh       32    2017  2017-04-28          Sunrisers Hyderabad
# Chennai          67    2008  2008-04-23          Chennai Super Kings
# Cuttack         186    2010  2010-03-19              Deccan Chargers
# Delhi            15    2017  2017-04-15             Delhi Daredevils
# Dharamsala      225    2010  2010-04-16              Kings XI Punjab
# Durban          123    2009  2009-04-21              Kings XI Punjab
# ...

# %%
(df['city'] == 'Mumbai').sum()
# Out:
# np.int64(85)

# %%
city.groups
# Out:
# {'Abu Dhabi': [457, 459, 460, 464, 470, 471, 475], 'Ahmedabad': [179, 186, 194, 197, 481, 486, 497, 500, 525, 532, 535, 539], 'Bangalore': [4, 11, 16, 29, 41, 44, 56, 57, 59, 69, 73, 83, 89, 103, 110, 180, 183, 191, 196, 213, 216, 225, 241, 267, 279, 282, 290, 301, 311, 316, 325, 328, 349, 355, 366, 378, 382, 391, 400, 406, 410, 428, 431, 451, 480, 487, 491, 494, 509, 516, 524, 533, 537, 545, 549, 556, 570, 579, 586, 605, 610, 616, 619, 625, 632, 635], 'Bloemfontein': [160, 164], 'Cape Town': [117, 118, 119, 120, 123, 125, 129], 'Centurion': [132, 135, 136, 146, 147, 148, 155, 156, 165, 169, 170, 171], 'Chandigarh': [31, 34, 45, 47, 60, 68, 72, 80, 93, 96, 107, 176, 192, 195, 204, 214, 242, 255, 283, 286, 320, 329, 332, 339, 353, 365, 390, 399, 408, 435, 439, 447, 504, 508, 511, 543, 551, 565, 568, 578, 585, 588, 596, 611, 614, 621], 'Chennai': [66, 70, 78, 84, 90, 106, 109, 178, 189, 201, 205, 210, 221, 223, 234, 247, 261, 271, 275, 288, 296, 305, 306, 307, 319, 331, 333, 342, 346, 
# ...

# %%
city.get_group('Mumbai').shape
# Out:
# (85, 18)

# %%
city.sum()  # look at this.. always apply sum on numerical values not the strings..
# Out:
#                    id  season  \
# city
# Abu Dhabi        3263   14098
# Ahmedabad        4863   24156
# Bangalore       22299  132861
# Bloemfontein      326    4018
# Cape Town         858   14063
# Centurion        1842   24108
# Chandigarh      15325   92582
# Chennai         15096   96554
# Cuttack          2534   14086
# Delhi           19600  120771
# Dharamsala       2949   18103
# Durban           2147   30135
# East London       432    6027
# Hyderabad       15907   98649
# Indore            618   10073
# Jaipur           9210   66363
# Johannesburg     1279   16072
# Kanpur           1358    8066
# Kimberley         458    6027
# Kochi            1301   10055
# Kolkata         19973  122783
# Mumbai          26283  171049
# Nagpur            646    6030
# Port Elizabeth    980   14063
# Pune            11238   64455
# Raipur           3229   12088
# Rajkot           3075   20165
# Ranchi           3439   14097
# Sharjah          2804   12084
# ...

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.head(1)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Sunrisers Hyderabad           35               0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2  umpire3
# 0  NJ Llong      NaN

# %%
df['player_of_match'].loc[1:11]
# Out:
# 1       SPD Smith
# 2         CA Lynn
# 3      GJ Maxwell
# 4       KM Jadhav
# 5     Rashid Khan
# 6          N Rana
# 7        AR Patel
# 8       SV Samson
# 9       JJ Bumrah
# 10      SP Narine
# 11     KA Pollard
# Name: player_of_match, dtype: object

# %%
df.groupby('player_of_match').size().sort_values(ascending=False).head(5)
# Out:
# player_of_match
# CH Gayle          18
# YK Pathan         16
# AB de Villiers    15
# DA Warner         15
# RG Sharma         14
# dtype: int64

# %%
 wickets = df.groupby('win_by_wickets')

# %%
wickets['win_by_runs'].sum().sort_values(ascending=False).head()
# Out:
# win_by_wickets
# 0    8702
# 1       0
# 2       0
# 3       0
# 4       0
# Name: win_by_runs, dtype: int64

# %%
df.groupby('win_by_wickets').size().sort_values(ascending=False).head()
# Out:
# win_by_wickets
# 0    297
# 7     70
# 6     68
# 5     57
# 8     48
# dtype: int64

# %% [markdown]
# *The **isin() function** is used to filter rows where the values match a given list or set of values.*

# %%
df['team1'].isin(['Mumbai Indians' , 'Chennai Super Kings'])
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: team1, Length: 636, dtype: bool

# %% [markdown]
# ***Pivot table-- It used to change the table view to get better insights of the data..***

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# ***Importing a zip file in colab***

# %%
from google.colab import files
uploaded = files.upload()  # Select and upload the .zip or .csv file
# Out:
#      <input type="file" id="files-ed254896-6d79-4d93-8a4a-d04608d27dab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed254896-6d79-4d93-8a4a-d04608d27dab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

with zipfile.ZipFile('archive.zip', 'r') as zip_ref:
    zip_ref.extractall('archive')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# If it's a CSV
data = pd.read_csv('archive/nutrients_csvfile.csv')

display(data.head())
# Out:
#                     Food Measure  Grams Calories Protein Fat Sat.Fat Fiber  \
# 0             Cows' milk   1 qt.    976      660      32  40      36     0
# 1              Milk skim   1 qt.    984      360      36   t       t     0
# 2             Buttermilk   1 cup    246      127       9   5       4     0
# 3  Evaporated, undiluted   1 cup    252      345      16  20      18     0
# 4         Fortified milk  6 cups  1,419    1,373      89  42      23   1.4
#
#   Carbs        Category
# 0    48  Dairy products
# 1    52  Dairy products
# 2    13  Dairy products
# 3    24  Dairy products
# 4   119  Dairy products

# %%
import os

# List the contents of the extracted directory
extracted_files = os.listdir('archive')
print("Files in the 'archive' directory:", extracted_files)
# Out:
# Files in the 'archive' directory: ['nutrients_csvfile.csv']

# %%
data.head()
# Out:
#                     Food Measure  Grams Calories Protein Fat Sat.Fat Fiber  \
# 0             Cows' milk   1 qt.    976      660      32  40      36     0
# 1              Milk skim   1 qt.    984      360      36   t       t     0
# 2             Buttermilk   1 cup    246      127       9   5       4     0
# 3  Evaporated, undiluted   1 cup    252      345      16  20      18     0
# 4         Fortified milk  6 cups  1,419    1,373      89  42      23   1.4
#
#   Carbs        Category
# 0    48  Dairy products
# 1    52  Dairy products
# 2    13  Dairy products
# 3    24  Dairy products
# 4   119  Dairy products

# %%
data
# Out:
#                       Food Measure  Grams Calories Protein Fat Sat.Fat Fiber  \
# 0               Cows' milk   1 qt.    976      660      32  40      36     0
# 1                Milk skim   1 qt.    984      360      36   t       t     0
# 2               Buttermilk   1 cup    246      127       9   5       4     0
# 3    Evaporated, undiluted   1 cup    252      345      16  20      18     0
# 4           Fortified milk  6 cups  1,419    1,373      89  42      23   1.4
# ..                     ...     ...    ...      ...     ...  ..     ...   ...
# 330    Fruit-flavored soda  12 oz.    346      161       0   0       0     0
# 331             Ginger ale  12 oz.    346      105       0   0       0     0
# 332              Root beer  12 oz.    346      140       0   0       0     0
# 333                 Coffee   1 cup    230        3       t   0       0     0
# 334                    Tea   1 cup    230        4       0   t       0     0
#
#     Carbs                   Category
# ...

# %%
data.head()
# Out:
#                     Food Measure  Grams Calories Protein Fat Sat.Fat Fiber  \
# 0             Cows' milk   1 qt.    976      660      32  40      36     0
# 1              Milk skim   1 qt.    984      360      36   t       t     0
# 2             Buttermilk   1 cup    246      127       9   5       4     0
# 3  Evaporated, undiluted   1 cup    252      345      16  20      18     0
# 4         Fortified milk  6 cups  1,419    1,373      89  42      23   1.4
#
#   Carbs        Category
# 0    48  Dairy products
# 1    52  Dairy products
# 2    13  Dairy products
# 3    24  Dairy products
# 4   119  Dairy products

# %%
data
# Out:
#                       Food Measure  Grams  Calories  Protein   Fat  Sat.Fat  \
# 0               Cows' milk   1 qt.  976.0     660.0     32.0  40.0     36.0
# 1                Milk skim   1 qt.  984.0     360.0     36.0   0.0      0.0
# 2               Buttermilk   1 cup  246.0     127.0      9.0   5.0      4.0
# 3    Evaporated, undiluted   1 cup  252.0     345.0     16.0  20.0     18.0
# 4           Fortified milk  6 cups    0.0       0.0     89.0  42.0     23.0
# ..                     ...     ...    ...       ...      ...   ...      ...
# 330    Fruit-flavored soda  12 oz.  346.0     161.0      0.0   0.0      0.0
# 331             Ginger ale  12 oz.  346.0     105.0      0.0   0.0      0.0
# 332              Root beer  12 oz.  346.0     140.0      0.0   0.0      0.0
# 333                 Coffee   1 cup  230.0       3.0      0.0   0.0      0.0
# 334                    Tea   1 cup  230.0       4.0      0.0   0.0      0.0
#
#      Fiber  Carbs                   Category
# ...

# %%
data.head(2)
# Out:
#          Food Measure  Grams  Calories  Protein   Fat  Sat.Fat  Fiber  Carbs  \
# 0  Cows' milk   1 qt.  976.0     660.0     32.0  40.0     36.0    0.0   48.0
# 1   Milk skim   1 qt.  984.0     360.0     36.0   0.0      0.0    0.0   52.0
#
#          Category
# 0  Dairy products
# 1  Dairy products

# %%
data.pivot_table(index='Food' , columns='Grams' , values='Calories' , aggfunc='mean').head(3)
# Out:
# Grams                0.0    11.0   12.0   14.0   15.0   16.0   17.0   20.0   \
# Food
# (1/2 cup ice cream)    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# (cornstarch)           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3 teaspoons sugar      NaN    NaN   50.0    NaN    NaN    NaN    NaN    NaN
#
# Grams                23.0   25.0   ...  285.0  300.0  346.0  380.0  454.0  \
# Food                               ...
# (1/2 cup ice cream)    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
# (cornstarch)           NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
# 3 teaspoons sugar      NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
#
# Grams                480.0  540.0  925.0  976.0  984.0
# Food
# (1/2 cup ice cream)    NaN  690.0    NaN    NaN    NaN
# (cornstarch)           NaN    NaN    NaN    NaN    NaN
# 3 teaspoons sugar      NaN    NaN    NaN    NaN    NaN
#
# [3 rows x 103 columns]

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
df.pivot_table(index='city', columns='winner', values='win_by_runs', aggfunc='sum').tail(5)
# Out:
# winner         Chennai Super Kings  Deccan Chargers  Delhi Daredevils  \
# city
# Raipur                         NaN              NaN              15.0
# Rajkot                         NaN              NaN               0.0
# Ranchi                        34.0              NaN               NaN
# Sharjah                        0.0              NaN               0.0
# Visakhapatnam                 74.0              NaN               4.0
#
# winner         Gujarat Lions  Kings XI Punjab  Kochi Tuskers Kerala  \
# city
# Raipur                   NaN              NaN                   NaN
# Rajkot                   0.0             49.0                   NaN
# Ranchi                   NaN              NaN                   NaN
# Sharjah                  NaN             72.0                   NaN
# Visakhapatnam            NaN              0.0                   NaN
#
# winner         Kolkata Knight Riders  Mumbai Indians  Pune Warriors  \
# city
# ...

# %% [markdown]
# # ***Rename Funnction***

# %%
data.head(2)
# Out:
#          Food Measure  Grams  Calories  Protein   Fat  Sat.Fat  Fiber  Carbs  \
# 0  Cows' milk   1 qt.  976.0     660.0     32.0  40.0     36.0    0.0   48.0
# 1   Milk skim   1 qt.  984.0     360.0     36.0   0.0      0.0    0.0   52.0
#
#          Category
# 0  Dairy products
# 1  Dairy products

# %%
data.rename(columns = {'Grams' : 'weights' , 'Category' : 'Type' })
# Out:
#                       Food Measure  weights  Calories  Protein   Fat  Sat.Fat  \
# 0               Cows' milk   1 qt.    976.0     660.0     32.0  40.0     36.0
# 1                Milk skim   1 qt.    984.0     360.0     36.0   0.0      0.0
# 2               Buttermilk   1 cup    246.0     127.0      9.0   5.0      4.0
# 3    Evaporated, undiluted   1 cup    252.0     345.0     16.0  20.0     18.0
# 4           Fortified milk  6 cups      0.0       0.0     89.0  42.0     23.0
# ..                     ...     ...      ...       ...      ...   ...      ...
# 330    Fruit-flavored soda  12 oz.    346.0     161.0      0.0   0.0      0.0
# 331             Ginger ale  12 oz.    346.0     105.0      0.0   0.0      0.0
# 332              Root beer  12 oz.    346.0     140.0      0.0   0.0      0.0
# 333                 Coffee   1 cup    230.0       3.0      0.0   0.0      0.0
# 334                    Tea   1 cup    230.0       4.0      0.0   0.0      0.0
#
# ...

# %%
data.head()
# Out:
#                     Food Measure  Grams  Calories  Protein   Fat  Sat.Fat  \
# 0             Cows' milk   1 qt.  976.0     660.0     32.0  40.0     36.0
# 1              Milk skim   1 qt.  984.0     360.0     36.0   0.0      0.0
# 2             Buttermilk   1 cup  246.0     127.0      9.0   5.0      4.0
# 3  Evaporated, undiluted   1 cup  252.0     345.0     16.0  20.0     18.0
# 4         Fortified milk  6 cups    0.0       0.0     89.0  42.0     23.0
#
#    Fiber  Carbs        Category
# 0    0.0   48.0  Dairy products
# 1    0.0   52.0  Dairy products
# 2    0.0   13.0  Dairy products
# 3    0.0   24.0  Dairy products
# 4    1.4  119.0  Dairy products

# %% [markdown]
# ***# Corr Function***

# %%
df.corr() # It tell correlation between series.. But data should be in numerical format
# Otherwise, It willl give error like below..
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-196-1791540609> in <cell line: 0>()
# ----> 1 df.corr() # It tell correlation between series.. But data should be in numerical format
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
# ...

# %%
df.set_index('city')  # It makes columns as index
# Out:
#             id  season        date                        team1  \
# city
# Hyderabad    1    2017  2017-04-05          Sunrisers Hyderabad
# Pune         2    2017  2017-04-06               Mumbai Indians
# Rajkot       3    2017  2017-04-07                Gujarat Lions
# Indore       4    2017  2017-04-08       Rising Pune Supergiant
# Bangalore    5    2017  2017-04-08  Royal Challengers Bangalore
# ...        ...     ...         ...                          ...
# Raipur     632    2016  2016-05-22             Delhi Daredevils
# Bangalore  633    2016  2016-05-24                Gujarat Lions
# Delhi      634    2016  2016-05-25          Sunrisers Hyderabad
# Delhi      635    2016  2016-05-27                Gujarat Lions
# Bangalore  636    2016  2016-05-29          Sunrisers Hyderabad
#
#                                  team2                  toss_winner  \
# city
# Hyderabad  Royal Challengers Bangalore  Royal Challengers Bangalore
# ...

# %%
df.reset_index() # it reset the column format to orignal
# Out:
#      index   id  season       city        date                        team1  \
# 0        0    1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        1    2    2017       Pune  2017-04-06               Mumbai Indians
# 2        2    3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3        3    4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4        4    5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...  ...     ...        ...         ...                          ...
# 631    631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632    632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633    633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634    634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635    635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
# ...

# %%
# Reset function is also used To convert Series into DataFrames

# %%
data['Food'].value_counts()
# Out:
# Food
# Butter              3
# Whole-wheat         2
# Ice cream           2
# Custard             2
# Fresh, raw          2
#                    ..
# Cauliflower         1
# Strips, from raw    1
# Raw, grated         1
# Carrots             1
# Cucumbers           1
# Name: count, Length: 329, dtype: int64

# %% [markdown]
# ***Dropna is used to drop- null values***

# %%
data.dropna().shape # it means data does contain any null value to delete
# Out:
# (335, 10)

# %%
data.shape
# Out:
# (335, 10)

# %%
df.dropna().shape # On the basis of row by-default... Axis = 0
# Out:
# (0, 18)

# %%
df.shape
# Out:
# (636, 18)

# %%
data.dropna(axis=1).shape #  Now see that.. SO cols and rows are dropped on the basis of Columnn
# Out:
# (335, 10)

# %%
 data.dropna(how = 'all').shape  # if all the row is null then drop. otherwise don't drop on the basis of single value
# Out:
# (335, 10)

# %% [markdown]
# Fillna()

# %%
data.fillna(0) # missing values got zero value
# Out:
#                       Food Measure  Grams  Calories  Protein   Fat  Sat.Fat  \
# 0               Cows' milk   1 qt.  976.0     660.0     32.0  40.0     36.0
# 1                Milk skim   1 qt.  984.0     360.0     36.0   0.0      0.0
# 2               Buttermilk   1 cup  246.0     127.0      9.0   5.0      4.0
# 3    Evaporated, undiluted   1 cup  252.0     345.0     16.0  20.0     18.0
# 4           Fortified milk  6 cups    0.0       0.0     89.0  42.0     23.0
# ..                     ...     ...    ...       ...      ...   ...      ...
# 330    Fruit-flavored soda  12 oz.  346.0     161.0      0.0   0.0      0.0
# 331             Ginger ale  12 oz.  346.0     105.0      0.0   0.0      0.0
# 332              Root beer  12 oz.  346.0     140.0      0.0   0.0      0.0
# 333                 Coffee   1 cup  230.0       3.0      0.0   0.0      0.0
# 334                    Tea   1 cup  230.0       4.0      0.0   0.0      0.0
#
#      Fiber  Carbs                   Category
# ...

# %%
data['Measure'].fillna("Not Specified")  # use it for column contains string values... Not for numeric
# Out:
# 0       1 qt.
# 1       1 qt.
# 2       1 cup
# 3       1 cup
# 4      6 cups
#         ...
# 330    12 oz.
# 331    12 oz.
# 332    12 oz.
# 333     1 cup
# 334     1 cup
# Name: Measure, Length: 335, dtype: object
